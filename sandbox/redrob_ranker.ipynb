# %% [markdown]
# # Redrob Hackathon — Resume Ranker
#
# This notebook runs the full candidate ranking pipeline in your browser (no GPU needed, no API key needed, no setup needed).

# %%
# Cell 1 — Clone the repo
import os, sys
REPO = "https://github.com/suryanshk0920/resume_ranker.git"
if not os.path.exists("resume_ranker"):
    # !git clone --quiet {REPO} 2>/dev/null
# %cd resume_ranker
sys.path.insert(0, ".")

# %%
# Cell 2 — Install dependencies
# !pip install torch torchvision --quiet --index-url https://download.pytorch.org/whl/cpu
# !pip install -r requirements.txt gdown --quiet
print("Dependencies installed")

# %%
# Cell 3 — Download candidates.jsonl (465 MB)
import os
FILE_ID = "1mYMwXzWbZUfaaoA3krP2682TWYKRvl0s"
os.makedirs("data", exist_ok=True)
# !gdown --id {FILE_ID} -O data/candidates.jsonl --quiet
size = os.path.getsize("data/candidates.jsonl") / 1e6
print(f"Downloaded {size:.0f} MB to data/candidates.jsonl")

# %%
# Cell 4 — Run the pipeline
import time
t0 = time.time()
# !python run.py
print(f"\nTotal wall time: {time.time() - t0:.1f}s")

# %%
# Cell 5 — View results and download
import pandas as pd
df = pd.read_csv("output/submission.csv")
print("Top 10 candidates:")
print(df.head(10).to_string(index=False))
print(f"\nTotal: {len(df)} rows")
from google.colab import files
files.download("output/submission.csv")
